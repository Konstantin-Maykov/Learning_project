# %% [markdown]
# # Анализ бизнес-показателей развлекательного приложения

# %% [markdown]
# <h1>План<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Общий-вывод-по-п.-2" data-toc-modified-id="Общий-вывод-по-п.-2-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Общий вывод по п. 2</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Приведение-названий-столбцов-соответствие-с-хорошим-стилем" data-toc-modified-id="Приведение-названий-столбцов-соответствие-с-хорошим-стилем-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Приведение названий столбцов соответствие с хорошим стилем</a></span></li><li><span><a href="#Преобразование-данных-столбцов-в-тип-datetime" data-toc-modified-id="Преобразование-данных-столбцов-в-тип-datetime-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Преобразование данных столбцов в тип datetime</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Проверка-на-неявные-дубликаты" data-toc-modified-id="Проверка-на-неявные-дубликаты-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проверка на неявные дубликаты</a></span></li><li><span><a href="#Проверка-на-явные-аномалии" data-toc-modified-id="Проверка-на-явные-аномалии-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Проверка на явные аномалии</a></span></li><li><span><a href="#Выводы-по-пункту-3" data-toc-modified-id="Выводы-по-пункту-3-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Выводы по пункту 3</a></span></li></ul></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функции-для-вычисления-метрик" data-toc-modified-id="Функции-для-вычисления-метрик-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Функции для вычисления метрик</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li></ul></li><li><span><a href="#Функции-для-построения-графиков" data-toc-modified-id="Функции-для-построения-графиков-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Функции для построения графиков</a></span><ul class="toc-item"><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-построения-графика-удержания" data-toc-modified-id="Функция-для-построения-графика-удержания-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Функция для построения графика удержания</a></span></li><li><span><a href="#Функция-для-построения-графика-конверсии" data-toc-modified-id="Функция-для-построения-графика-конверсии-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Функция для построения графика конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составление-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей" data-toc-modified-id="Составление-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Составление профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей</a></span></li><li><span><a href="#Определение-стран-из-которых-пользователи-приходят-в-приложение.-Нахождение-страны-на-которую-приходится-больше-всего-платящих-пользователей" data-toc-modified-id="Определение-стран-из-которых-пользователи-приходят-в-приложение.-Нахождение-страны-на-которую-приходится-больше-всего-платящих-пользователей-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Определение стран из которых пользователи приходят в приложение. Нахождение страны на которую приходится больше всего платящих пользователей</a></span></li><li><span><a href="#Определение-устройств,-которыми-пользуются-клиенты,-и-какие-устройства-предпочитают-платящие-пользователи" data-toc-modified-id="Определение-устройств,-которыми-пользуются-клиенты,-и-какие-устройства-предпочитают-платящие-пользователи-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Определение устройств, которыми пользуются клиенты, и какие устройства предпочитают платящие пользователи</a></span></li><li><span><a href="#Изучение-рекламных-источников-привлечения-и-определение-каналов,-из-которых-пришло-больше-всего-платящих-пользователей" data-toc-modified-id="Изучение-рекламных-источников-привлечения-и-определение-каналов,-из-которых-пришло-больше-всего-платящих-пользователей-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Изучение рекламных источников привлечения и определение каналов, из которых пришло больше всего платящих пользователей</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расчет-общей-суммы-расходов-на-маркетинг" data-toc-modified-id="Расчет-общей-суммы-расходов-на-маркетинг-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Расчет общей суммы расходов на маркетинг</a></span></li><li><span><a href="#Распределение-трат-по-рекламным-источникам" data-toc-modified-id="Распределение-трат-по-рекламным-источникам-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Распределение трат по рекламным источникам</a></span></li><li><span><a href="#Визуализация-динамики-изменения-расходов-во-времени--по-каждому-источнику" data-toc-modified-id="Визуализация-динамики-изменения-расходов-во-времени--по-каждому-источнику-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Визуализация динамики изменения расходов во времени  по каждому источнику</a></span></li><li><span><a href="#Средняя-стоимость-привлечения-одного-пользователя-(CAC)" data-toc-modified-id="Средняя-стоимость-привлечения-одного-пользователя-(CAC)-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Средняя стоимость привлечения одного пользователя (CAC)</a></span></li><li><span><a href="#Общий-вывод-по-пунку-5" data-toc-modified-id="Общий-вывод-по-пунку-5-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Общий вывод по пунку 5</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы" data-toc-modified-id="Анализ-окупаемости-рекламы-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы</a></span></li><li><span><a href="#Проверка-конверсии-и-удержания-пользователей-и-динамику-их-изменений" data-toc-modified-id="Проверка-конверсии-и-удержания-пользователей-и-динамику-их-изменений-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Проверка конверсии и удержания пользователей и динамику их изменений</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-о-низкой-конверсии-пользователей-по-устройствам" data-toc-modified-id="Проверка-гипотезы-о-низкой-конверсии-пользователей-по-устройствам-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Проверка гипотезы о низкой конверсии пользователей по устройствам</a></span></li><li><span><a href="#Проверка-гипотезы-о-низком-удержании--пользователей-по-устройствам" data-toc-modified-id="Проверка-гипотезы-о-низком-удержании--пользователей-по-устройствам-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Проверка гипотезы о низком удержании  пользователей по устройствам</a></span></li></ul></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-о-низкой-конверсии-пользователей-по-странам" data-toc-modified-id="Проверка-гипотезы-о-низкой-конверсии-пользователей-по-странам-8.4.1"><span class="toc-item-num">8.4.1&nbsp;&nbsp;</span>Проверка гипотезы о низкой конверсии пользователей по странам</a></span></li><li><span><a href="#Проверка-гипотезы-о-низком-удержании-пользователей-по-странам" data-toc-modified-id="Проверка-гипотезы-о-низком-удержании-пользователей-по-странам-8.4.2"><span class="toc-item-num">8.4.2&nbsp;&nbsp;</span>Проверка гипотезы о низком удержании пользователей по странам</a></span></li></ul></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-о-низкой-конверсии-пользователей-по-каналам" data-toc-modified-id="Проверка-гипотезы-о-низкой-конверсии-пользователей-по-каналам-8.5.1"><span class="toc-item-num">8.5.1&nbsp;&nbsp;</span>Проверка гипотезы о низкой конверсии пользователей по каналам</a></span></li><li><span><a href="#Проверка-гипотезы-о-низком-удержании-пользователей-по-каналам" data-toc-modified-id="Проверка-гипотезы-о-низком-удержании-пользователей-по-каналам-8.5.2"><span class="toc-item-num">8.5.2&nbsp;&nbsp;</span>Проверка гипотезы о низком удержании пользователей по каналам</a></span></li></ul></li><li><span><a href="#Общие-выводы-по-п.-7" data-toc-modified-id="Общие-выводы-по-п.-7-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Общие выводы по п. 7</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#Возможные-причины-неэффективности-привлечения-пользователей" data-toc-modified-id="Возможные-причины-неэффективности-привлечения-пользователей-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Возможные причины неэффективности привлечения пользователей</a></span></li><li><span><a href="#Рекомендации-для-отдела-маркетинга" data-toc-modified-id="Рекомендации-для-отдела-маркетинга-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Рекомендации для отдела маркетинга</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Несмотря на большие вложения в рекламу развлекательного приложения HakunaMatata, последние несколько месяцев компания терпит убытки. Задача — разобраться в причинах и помочь компании выйти в плюс. Для этого необходимо узнать:
# - откуда приходят пользователи, и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Даны три датасета, в которых хранится информация о привлеченных пользователях с 1 мая по 27 октября 2019 года:
#
# 1-ый датасет хранит лог сервера с данными об их посещениях.
#
# 2-ой - выгрузка покупок за указанный период.
#
# 3-ий - рекламные расходы.

# %% [markdown]
# ## Изучение общей информации

# %%
# импортирую необходимые бибилотеки для проведения исследования
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
# считываю файлы 'visits_info_short.csv', 'orders_info_short.csv', 'costs_info_short.csv'
# и сохраняю в переменные visits, orders, costs соответственно
try:
    visits = pd.read_csv('C:/Users/USER/Desktop/Исходники/Анализ бизнес показателей/visits_info_short.csv')
    orders = pd.read_csv ('C:/Users/USER/Desktop/Исходники/Анализ бизнес показателей/orders_info_short.csv')
    costs = pd.read_csv('C:/Users/USER/Desktop/Исходники/Анализ бизнес показателей/costs_info_short.csv')
except:
    print('FileNotFoundError')

# %%
# открываю первые пять строк датасета visits
visits.head(5)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
# вывожу общую информацию для датасета visits
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# **Выводы по датафрейму visits**
#
# 1. Датасет состоит из 6 столбцов и 309901 строки.
# 2. Пропусков в данных нет.
# 3. Необходимо названия столбцов перевести в нижний и змеиный регистры.
# 4. Преобразовать данные в столбцах Session Start и Session End в тип datetime.

# %%
# открываю первые пять строк датасета orders
orders.head(5)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
# вывожу общую информацию для датасета orders
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# **Выводы по датафрейму orders**
#
# 1. Датасет состоит из 3-х столбцов и 40212 строк.
# 2. Пропусков в данных нет.
# 3. Необходимо названия столбцов перевести в нижний и змеиный регистры.
# 4. Преобразовать данные в столбце Event Dt в тип datetime.

# %%
# открываю первые пять строк датасета costs
costs.head(5)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
# вывожу общую информацию для датасета costs
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# **Выводы по датафрейму costs**
#
# 1. Датасет состоит из 3-х столбцов и 1800 строк.
# 2. Пропусков в данных нет.
# 3. Необходимо названия столбцов перевести в нижний регистр.
# 4. Преобразовать данные в столбце dt в тип datetime.

# %% [markdown]
# ### Общий вывод по п. 2
#
# 1. Преобразовать в тип datetime столбцы: dt, Event Dt, Session Start и Session End.
# 2. Перевести названия столбцов во всех датасетах в нижний и змеиный регистры.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Приведение названий столбцов соответствие с хорошим стилем

# %%
# работа с датасетом visits
# приведение названий столбцов в нижний и змеиный регистры
visits.rename(columns=str.lower, inplace=True)
visits.rename(columns={'user id': 'user_id', 'session start': 'session_start', 'session end': 'session_end'}, inplace=True)

# %%
# приведение названий столбцов к нижнему регистру в датасете orders
orders.rename(columns=str.lower, inplace=True)
orders.rename(columns={'user id': 'user_id', 'event dt': 'event_dt'}, inplace=True)

# %%
# приведение названий столбцов к нижнему регистру в датасете costs
costs.rename(columns=str.lower, inplace=True)

# %% [markdown]
# ### Преобразование данных столбцов в тип datetime

# %%
# преобразование данных в столбцах Session Start и Session End в тип datetime
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %%
# преобразование данных в столбце Event Dt в тип datetime
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %%
# преобразование данных в столбце dt в тип datetime
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Проверка на явные дубликаты

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Проверка на неявные дубликаты

# %% [markdown]
# Для этого вывожу уникальные значения в стобцах с текстовыми значениями у датасетов visits и costs.

# %%
# уникальные значения для столбца region из visits
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %% [markdown]
# В столбце region неявных дубликатов на обнаружено.

# %%
# уникальные значения для столбца device из visits
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %% [markdown]
# В столбце device неявных дубликатов на обнаружено.

# %%
# уникальные значения для столбца channel из visits
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# В столбце channel неявных дубликатов на обнаружено.

# %%
# уникальные значения для столбца channel из costs
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявных дубликатов не обнаружено.

# %% [markdown]
# ### Проверка на явные аномалии

# %% [markdown]
# В данном случае явные аномалии - это отрицательные значения в расходах на рекламную компанию (стобец costs в датасете costs) и сумме заказа (столбец revenue в датасете orders).

# %%
# проверка значений столбца costs
len(costs[costs['costs'] < 0])
# Out:
# 0

# %%
len(orders[orders['revenue'] < 0])
# Out:
# 0

# %% [markdown]
# ### Выводы по пункту 3
#
# 1. В ходе предобработки данных привел названия столбцов датафреймов visits, orders, costs в нижний и змеиный регистры.
# 2. Преревел столбцы dt, event_dt, session_end, session_start в  тип datetime.
# 3. Явные дубликаты не обнаружил.
# 4. Явных аномалий не обнаружил.

# %% [markdown]
# ## Функции для расчёта и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функции для вычисления метрик

# %% [markdown]
# #### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    # нахожу параметры первых и последних посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяю дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляю признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    
    # считаю количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяю траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делю рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляю стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляю столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаю пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираю «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаю таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаю таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаю обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаю пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяю дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляю данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываю лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группирую по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делю каждую «ячейку» в строке на размер когорты
        # и получаю conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаю таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираю 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаю таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаю обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаю пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляю данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываю лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группирую по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строю «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # нахожу сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляю размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяю размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаю все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаю размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираю датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаю средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаю ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляю строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаю размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляю CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляю размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаю таблицы LTV и ROI
        return result, roi

    # получаю таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираю 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаю таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функции для построения графиков

# %% [markdown]
# #### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяю скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Функция для построения графика удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаю размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаю размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # если в индексах таблицы удержания только payer,
    # добавляю второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строю кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей', pad=30)

    # во второй ячейке строю кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(grid=True, ax=ax2)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей', pad=30)

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаю названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    
    # фильтрую данные и строю график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания платящих пользователей на {}-й день'.format(horizon), pad=30)

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтрую данные и строю график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания неплатящих пользователей на {}-й день'.format(horizon), pad=30)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для построения графика конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаю размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаю размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляю только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей', pad=30)

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon), pad=30)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаю сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляю только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишу в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаю размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляю только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[[horizon - 1]]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV', pad=30)

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon), pad=30)

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(index='dt', columns=columns, values='cac', aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей', pad=30)

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI', pad=30)

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon), pad=30)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Составление профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей

# %%
# получение профилей пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# определение минимальной и максимальной даты приывлечения пользователей
min_analysis_date = profiles['dt'].min()
max_analysis_date = profiles['dt'].max()
print('Минимальная дата привлечения пользователей:', min_analysis_date)
print('Максимальная дата привлечения пользователей:', max_analysis_date)
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# **Вывод**
#
# - Составил таблицу профилей пользователей.
# - Нашел минимальную и максимальную даты привлечения пользователей: 2019-05-01 и 2019-10-27 соответственно. Даты совпадают с датами, указанными в условиях задачи.

# %% [markdown]
# ### Определение стран из которых пользователи приходят в приложение. Нахождение страны на которую приходится больше всего платящих пользователей

# %%
# определение стран из которых пользователи приходят в приложение
print(profiles['region'].unique())
# Out:
# ['United States' 'France' 'Germany' 'UK']

# %%
# нахождение страны на которую приходится больше всего платящих пользователей
country_more_pay = (
    profiles
    .query('payer == True')
    .groupby('region')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'user_pay'})
    .sort_values(by='user_pay', ascending=False)
)
country_more_pay
# Out:
#                user_pay
# region
# United States      6902
# UK                  700
# France              663
# Germany             616

# %%
# построение таблицы, отражающую количество пользователей и долю платящих из каждой страны
country_more_pay['total_user'] = (
    profiles
    .groupby('region')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'total_user'})
)
country_more_pay['ratio_pay'] = country_more_pay['user_pay'] / country_more_pay['total_user']
country_more_pay = country_more_pay.drop(columns=['user_pay']).style.format({'ratio_pay': '{:.2%}'})
country_more_pay
# Out:
# <style type="text/css">
# </style>
# <table id="T_e149a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e149a_level0_col0" class="col_heading level0 col0" >total_user</th>
#       <th id="T_e149a_level0_col1" class="col_heading level0 col1" >ratio_pay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e149a_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_e149a_row0_col0" class="data row0 col0" >100002</td>
#       <td id="T_e149a_row0_col1" class="data row0 col1" >6.90%</td>
#     </tr>
#     <tr>
#       <th id="T_e149a_level0_row1" class="row_heading level0 row1" >UK</th>
#       <td id="T_e149a_row1_col0" class="data row1 col0" >17575</td>
#       <td id="T_e149a_row1_col1" class="data row1 col1" >3.98%</td>
#     </tr>
# ...

# %% [markdown]
# **Выводы**
#
# 1. Пользователи приходят из United States, France, Germany, UK.
# 2. Больше всего платящих пользоватлей приходится на США.
# 3. Больше всего пользователей в приложение приходит из США, меньше всего из Германии.
# 4. Доля платящих пользователей больше в США и равна 6.90%. За ней идет Германия с долей 4.11%.

# %% [markdown]
# ### Определение устройств, которыми пользуются клиенты, и какие устройства предпочитают платящие пользователи

# %%
# определение устройств, которыми пользуются пользователи
print(profiles['device'].unique())
# Out:
# ['Mac' 'iPhone' 'PC' 'Android']

# %%
# определение устройств, которыми пользуются платящие пользователи
profiles_payer = (
    profiles
    .query('payer == True')
    .groupby('device')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'user_pay'})
    .sort_values(by='user_pay', ascending=False)
)
profiles_payer
# Out:
#          user_pay
# device
# iPhone       3382
# Android      2050
# Mac          1912
# PC           1537

# %%
# построение таблицы, отражающую количество пользователей и долю платящих для каждого устройства
profiles_payer['total_user'] = (
    profiles
    .groupby('device')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'total_user'})
)
profiles_payer['ratio_pay'] = profiles_payer['user_pay'] / profiles_payer['total_user']
profiles_payer = profiles_payer.drop(columns=['user_pay']).style.format({'ratio_pay': '{:.2%}'})
profiles_payer
# Out:
# <style type="text/css">
# </style>
# <table id="T_aed75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aed75_level0_col0" class="col_heading level0 col0" >total_user</th>
#       <th id="T_aed75_level0_col1" class="col_heading level0 col1" >ratio_pay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >device</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aed75_level0_row0" class="row_heading level0 row0" >iPhone</th>
#       <td id="T_aed75_row0_col0" class="data row0 col0" >54479</td>
#       <td id="T_aed75_row0_col1" class="data row0 col1" >6.21%</td>
#     </tr>
#     <tr>
#       <th id="T_aed75_level0_row1" class="row_heading level0 row1" >Android</th>
#       <td id="T_aed75_row1_col0" class="data row1 col0" >35032</td>
#       <td id="T_aed75_row1_col1" class="data row1 col1" >5.85%</td>
#     </tr>
# ...

# %% [markdown]
# **Выводы**
#
# 1. Пользователи пользуются следующимим устройствами: iPhone, Android, Mac, PC.
# 2. Больше всего приложением пользуются пользователи с iPhone, меньше всего с Mac.
# 3. Платящие пользователи предпочитают iPhone. Второе место у пользователей с Android.
# 4. Доля платящих пользователей больше всего с Mac (6.364%), затем с iPhone (6.21%). Самая маленька конверсия у тех, кто имеет PC(5.05%).

# %% [markdown]
# ### Изучение рекламных источников привлечения и определение каналов, из которых пришло больше всего платящих пользователей

# %%
# определение рекламных источников привлечения
print(profiles['channel'].unique())
# Out:
# ['FaceBoom' 'organic' 'AdNonSense' 'YRabbit' 'MediaTornado'
#  'RocketSuperAds' 'LeapBob' 'TipTop' 'WahooNetBanner' 'OppleCreativeMedia'
#  'lambdaMediaAds']

# %%
# определение каналов, из которых пришло больше всео платящих пользователей
profiles_channel = (
    profiles
    .query('payer == True')
    .groupby('channel')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'user_pay'})
    .sort_values(by='user_pay', ascending=False)
)
profiles_channel
# Out:
#                     user_pay
# channel
# FaceBoom                3557
# TipTop                  1878
# organic                 1160
# WahooNetBanner           453
# AdNonSense               440
# RocketSuperAds           352
# LeapBob                  262
# OppleCreativeMedia       233
# lambdaMediaAds           225
# YRabbit                  165
# MediaTornado             156

# %%
# построение таблицы, отражающую количество пользователей и долю платящих для каждого канала привлечения
profiles_channel['total_user'] = (
    profiles
    .groupby('channel')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'total_user'})
    )
profiles_channel['ratio_pay'] = profiles_channel['user_pay'] / profiles_channel['total_user']
profiles_channel = profiles_channel.drop('user_pay', axis=1)
profiles_channel.sort_values(by='total_user', ascending=False).style.format({'ratio_pay': '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_60b0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60b0f_level0_col0" class="col_heading level0 col0" >total_user</th>
#       <th id="T_60b0f_level0_col1" class="col_heading level0 col1" >ratio_pay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60b0f_level0_row0" class="row_heading level0 row0" >organic</th>
#       <td id="T_60b0f_row0_col0" class="data row0 col0" >56439</td>
#       <td id="T_60b0f_row0_col1" class="data row0 col1" >2.06%</td>
#     </tr>
#     <tr>
#       <th id="T_60b0f_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#       <td id="T_60b0f_row1_col0" class="data row1 col0" >29144</td>
#       <td id="T_60b0f_row1_col1" class="data row1 col1" >12.20%</td>
#     </tr>
# ...

# %% [markdown]
# **Выводы**
# 1. В приложение пользователи приходят из 11-ти каналов: FaceBoom, organic, AdNonSense, YRabbit, MediaTornado, RocketSuperAds, LeapBob, TipTop, WahooNetBanner, OppleCreativeMedia, lambdaMediaAds.
# 2. Платящих пользователей приходит болше всего из FaceBoom, затем идет FaceBoom, на третьем месте organic.
# 3. Меньше всего платящих пользователей пришло из MediaTornado.
# 4. Больше всего пользователей приходит из канала organic, но при этом у него самая маленькая доля покупающих (2.06%). Стоит узнать, что является причиной невысокой конверсии у этого канала.
# 5. Второе место по количеству пришедших пользователей занимает FaceBoom, при этом у него самая высокая доля покупающих из всех каналов.
# 6. Второе место по доле покупающих занимает AdNonSense.
# 7. Меньше всего пользоватлей приходит из lambdaMediaAds.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Расчет общей суммы расходов на маркетинг

# %%
print('Общая сумма расходов на маркетинг:', costs['costs'].sum().round())
# Out:
# Общая сумма расходов на маркетинг: 105497.0

# %% [markdown]
# ### Распределение трат по рекламным источникам

# %%
costs_group = (
    costs
    .groupby('channel')
    .agg({'costs': 'sum'})
    .rename(columns={'costs': 'total_costs'})
    .sort_values(by='total_costs', ascending=False)
)
costs_group
# Out:
#                     total_costs
# channel
# TipTop                 54751.30
# FaceBoom               32445.60
# WahooNetBanner          5151.00
# AdNonSense              3911.25
# OppleCreativeMedia      2151.25
# RocketSuperAds          1833.00
# LeapBob                 1797.60
# lambdaMediaAds          1557.60
# MediaTornado             954.48
# YRabbit                  944.22

# %% [markdown]
# **Выводы**
#
# 1. Больше всего затрат на рекламу у канала TipTop. На втором месте FaceBoom. Причем затраты на рекламу у этих двух источников значительно превышают остальные.
# 2. Меньше всего затрат на рекламу у YRabbit и MediaTornado.

# %% [markdown]
# ### Визуализация динамики изменения расходов во времени  по каждому источнику

# %%
# добавляю в датасет costs столбцы с номерами недели и месяца
costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['month'] = pd.to_datetime(costs['dt']).dt.month

# %%
# устанавливаю размеры графиков
plt.figure(figsize = (20, 10))

# график 1
ax1 = plt.subplot(1, 2, 1)
costs.pivot_table(
    index='week',
    columns='channel',
    values='costs',
    aggfunc='sum'
).plot(grid=True, ax=ax1)
plt.legend()
plt.xlabel('Неделя')
plt.ylabel('Суммарные затраты')
plt.title('Динамика изменения расходов по неделям', pad=30)

# график 2
ax2 = plt.subplot(1, 2, 2)
costs.pivot_table(
    index='month',
    columns='channel',
    values='costs',
    aggfunc='sum'
).plot(grid=True, ax=ax2)
plt.legend()
plt.xlabel('Неделя')
plt.ylabel('Суммарные затраты')
plt.title('Динамика изменения расходов по месяцам', pad=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы**
#
# 1. На графиках видно, что самые большие затраты у каналов TipTop и FaceBoom. Затраты на рекламу у обоих каналов значительно менялись от недели к неделе и имели тенденцию к росту, но у TipTop темп роста значительно выше.
# 2. Последние два месяца затраты на FaceBoom перестали расти и немного снизились.
# 3. Расходы на рекламу у остальных какналов находятся примерно на одном уровне, начиная с первой недели.

# %% [markdown]
# ### Средняя стоимость привлечения одного пользователя (CAC)

# %%
# средняя стоимость привлечения одного пользователя для каждого источника
cac_channel = (
    profiles
    .groupby('channel')
    .agg({'acquisition_cost': 'mean'})
    .sort_values(by='acquisition_cost', ascending = False)
    )
cac_channel
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
# общая средняя стоимость привлечения одного пользователя
cac_channel.mean().round(3)
# Out:
# acquisition_cost    0.687
# dtype: float64

# %%
# общая средняя стоимость привлечения одного пользователя без учета канала organic
round((profiles.query('channel != "organic"')['acquisition_cost'].mean()), 3)
# Out:
# 1.127

# %% [markdown]
# **Вывод**
#
# 1. Наибольшая стоимость привлечения одного пользователя у канала TipTop, равная 2.799003.
# 2. Общая средняя стиоимость превлечения с учетом канала organic равна 0,687. Без учета - 1,127.
# 3. Наименьшая средняя стоимость привлечения одного пользователя YRabbit, MediaTornado, LeapBob.

# %% [markdown]
# ### Общий вывод по пунку 5
#
# 1. Общая сумма расходов на маркетинг: 105497.0.
# 2. Наибольшая стоимость привлечения одного пользователя и большие затраты на рекламу у канала TipTop. Также темп роста затрат на рекламу у TipTop наибольший. Второй по этим показателям - FaceBoom.
# 3. Средняя стиоимость превлечения с учетом канала organic равна 0,687. Без учета - 1,127.
# 4. Меньше всего затрат на рекламу у YRabbit и MediaTornado.
# 5. Наименьшая средняя стоимость привлечения одного пользователя YRabbit, MediaTornado, LeapBob.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# В условии задачи сказано, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Исключаю органических пользователей, так как в условии идет речь о пользователях, на которых были произведены затраты на привлечение. Отсюда следует:

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ### Анализ окупаемости рекламы

# %%
# считаю LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строю графики LTV, ROI и графики динамики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Выводы**
#
# 1. Затраты на рекламу не окупаются. ROI не привысило уровня окупаемости и составляет чуть более 80%.
# 2. CAC сза 14 дней значительно вырос. Исходя из этого делаю вывод, что расходы на рекламу сильно увеличились.
# 3. Инвестиции перестают окупаться в июне.
# 4. По графику динамика LTV видно, что LTV за весь период наблюдений держится примерно на одном уровне.

# %% [markdown]
# ### Проверка конверсии и удержания пользователей и динамику их изменений

# %%
# строю графики конверсии пользователей

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# На графиках видно, что пользователи хорошо конверитруются в течение всего горизонта анализа.

# %%
# смотрою удержание

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# 1. Форма графиков удержания пользователей близка к обратно-экспоненциальной, также график платящих пользователей лежит выше, чем у неплатящих. Исходя из этого можно сделать вывод, что поведение кривых удержания выглядит ожидаемо.
# 2. Данные графики не раскрывают причину убытка компании.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
# добавляю разбивку по устройствам
dimensions = ['device']

# считаю LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# строю графики LTV, ROI и графики динамики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# **Выводы**
#
# 1. Пользователи с PC начинают окупаться на 11-й день жизни, а владельцы остальных устройств (Mac, Android, iPhone) вообще не окупаются. Больше всего убытка приносят пользователи с Mac и iPhone.
# 2. Стоимость привлечения пользователей, пришедших в начале мая, находится примерно на одном уровне для каждого типа устройств. Начиная с середины мая стоимость привлечения начинает возрастать. Наиболее резко стоимость привлечения растет у пользователей Mac и iPhone.
# 3. Рост стоимости привлечения пользователей для каждого устройства продолжается до середины сентября и выходит на плато.
# 4. К концу наблюдаемого периода (1 ноября 2019) видим, что стоимость привлечения пользователей с Mac и iPhone выросла больше, чем в 2 раза, с Android - чуть больше чем в 1,5 раза. Наименьший рост у владальцев PC, отсюда и их окупаемость.
# 5. LTV подвержен сезонности, но при этом стабилен.
# 6. Предполагаю, что плохая окупаемость зависит от низкой конверсии и удержания. Эту гипотезу надо проверить.

# %% [markdown]
# #### Проверка гипотезы о низкой конверсии пользователей по устройствам

# %%
# конверсия с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Вывод:**
# - Гипотеза о низкой конверсии Mac, Android, iPhone не подтвердилась. Конверсия на этих устройствах значительно выше, чем у пользователей с PC.
# - Компании стоит поработать над увеличением конверсии пользователей, заходящих с PC.

# %% [markdown]
# #### Проверка гипотезы о низком удержании  пользователей по устройствам

# %%
# удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
# - Гипотеза о том, что удержание пользователей, имеющих Mac, Android, iPhone, низкая, подтвердилась. При этом удержание клиентов с PC не намного выше
# - Компании надо поработать над удержанием пользователей на всех устройствах.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
# добавляю разбивку по странам
dimensions = ['region']

# считаю LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# строю графики LTV, ROI и графики динамики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# **Выводы**
#
# 1. Не окупаются пользователи, проживающие в США. Пользователи из других стран окупаются стабильно.
# 2. LTV зависит от сезона. При этом в США «пожизненная ценность» клиентов выше, чем у пользователей из других стран.
# 3. За рассматриваемый период стоимость привлечения пользователей из Франции, Германии и Англии в конце мая до середины июня снизилась и вышла на плато.
# 4. В США же стоимость привлечения пользователей выросла примерно в 2,5 раза.
# 5. Как и в предыдущем пункте проверим значения конверсии и удержания.

# %% [markdown]
# #### Проверка гипотезы о низкой конверсии пользователей по странам

# %%
# конверсия с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Вывод:**
# - Пользователи из США конвертируются хорошо. У других стран конверсия в районе 5%.
# - Над конверсией для Германии, Британии и Франции можно поработать.

# %% [markdown]
# #### Проверка гипотезы о низком удержании пользователей по странам

# %%
# удержание с разбивкой по странам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
#
# - График удержания платящих пользователей имеет резкие скачки и падения, скорее всего это говорит о том, что были какие-то проблемы с приложением у жителей из Германии, Британии и Франции.
# - Удержание пользователей из США ниже, чем в других странах, над этим надо работать.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
# добавляю разбивку по рекламным каналам
dimensions = ['channel']

# считаю LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# строю графики LTV, ROI и графики динамики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# **Выводы**
#
# 1. Пользователи, пришедшие из каналов TipTop, FaceBoom, AdNonSense не окупаются.
# 2. Пользователи, пришедшие из других каналов окупаются стабильно.
# 3. За рассматриваемый период стоимость привлечения выросла только у канала TipTop, причем значительно.
# 4. Стоимость привлечения у каналов FaceBoom и AdNonSense была изначально самая высокая, но она осталасась на том же уровне.
# 5. Больше прибыли принесли пользователи, пришедшие из канала yrabbit.

# %% [markdown]
# #### Проверка гипотезы о низкой конверсии пользователей по каналам

# %%
# конверсия с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# *Вывод*:
# - Конверсия пользователей, пришедших из неокупающихся каналов (TipTop, FaceBoom, AdNonSense), на хорошем уровне.
# - Над конверсией WahooNetBanner, YRabbit, RocketSuperAds, OppleCreativeMedia, LeapBob, MediaTornado можно поработать.

# %% [markdown]
# #### Проверка гипотезы о низком удержании пользователей по каналам

# %%
# удержание с разбивкой по каналам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
# - Графики удержания платных пользователей (кроме пришедших из FaceBoom, AdNonSense) не похожи на эталонный экспоненциальный вид. Это говорит о том, что у пользователей из этих каналов были большие проблемы с приложением и они его покинули.
# - Удержание пользователей, пришедших из FaceBoom, AdNonSense, очень низкая. С этим надо разбираться.

# %% [markdown]
# ### Общие выводы по п. 7
#
# 1. Реклама, направленная на привлечение пользователей в целом не окупается.
# 2. Негативное влияние на окупаемость рекламы могут оказывать пользователи:
# - из США,
# - имеющие Mac, iPhone или Android,
# - привлеченные в приложение из каналов TipTop, FaceBoom, AdNonSense.
# 3. Возможные проблемы окупаемости:
#
#
#     1. Низкое удержание пользователей:
#     - пришедших из каналов FaceBoom, AdNonSense;
#     - из США;
#     - на всех устойствах, на PC дела обстоят чуть лучше.
#
#     2. низкая конверсия пользователей:
#     - пришедших из каналов WahooNetBanner, YRabbit, RocketSuperAds, OppleCreativeMedia, LeapBob, MediaTornado;
#     - из Германии, Британии и Франции;
#     - имеющих PC.
#
#     3. Высокие затраты на рекламу:
#     - в каналах TipTop, FaceBoom, AdNonSense,
#     - для пользователей из США,
#     - для пользователей с Mac, Android, iPhone.
#
# 4. Рекомендации для рекламного отдела:
# - Снизить затраты на рекламу для: пользователей из США; владельцев Mac, Android, iPhone; канала TipTop.
# - Низкое удержание по каналам FaceBoom, AdNonSense может зависеть от того, что игра не соответствует рекламе на баннере. Например, реклама о шахматах, а приложение о шашках. Поэтому стоит пересмотреть рекламу и устранить имеющиеся неточности.
# - Проверить правильность выбора целевой аудитории, на которую нацелена реклама.
# - Стоит обратить внимание на привлечение пользователей не только тех, где уже высокая конверсия, но и с конверсией ниже.
# - Пересмотреть рекламную компанию и обратить внимание на другие источники привлечения пользователей.

# %% [markdown]
# ## Выводы

# %% [markdown]
# ### Возможные причины неэффективности привлечения пользователей

# %% [markdown]
# 1. Неправильный выбор целевой аудитории.
# 2. Игра не соотвтетсвует заявленному в рекламе на каналах FaceBoom, AdNonSense.
# 3. Увеличение затрат на рекламу только по тем параметрам, где конверсия пользователей самая высокая и близкая к этому значению. Потому что проще увеличить низкую конверсию, чем поднимать еще выше высокую. Принцип Парето в действии.
# 4. Невысокая и находящаяся примерно на одном уровне конверсия у пользователей из Германии, Англии и Франции может объясняться тем, что при попытке оплаты в приложении возникают ошибки технические сбои или приложение не принимает местную валюту. Это предположение справедливо и для пользователей на PC.
# 5. Низкое удержание платящих пользователей из США могут объясняться тем, что при покупке в приложении пользователь получает неполный доcтуп к бонусам. Например, реклама не отключается.
# 6. Необоснованное вложение денег в только рекламу на канале TipTop.

# %% [markdown]
# ### Рекомендации для отдела маркетинга

# %% [markdown]
# 1. Устранить технические неисправности в приложении.
# 2. Посмотреть насколько оптимально соотношение платного и бесплатного доступа в приложении.
# 3. Обратить внимание на привлечения пользователей, имеющих PC.
# 4. Доработать портрет целевой аудитории.
# 5. Обратить внимание каналы откуда пришло меньшее количество пользователей, особенно на каналы с высоким ROI:  Yrabbit, MediaTornado, lambdaMediaAds.
# 6. Поработать над привлечением пользователей из Германии, Британии и Франции.
# 7. Для удержания пользователей в приложении можно подключить персональные пуш-уведомления.
# 8. Продумать добавление тематических соревнований или событий, приуроченных, например, к Новому году или Рождеству.
# 9. Добавить бонусы для постоянных пользователей.
